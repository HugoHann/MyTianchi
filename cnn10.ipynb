# %%
import pandas as pd
import numpy as np
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.utils import np_utils

train_data = pd.read_csv(r'/mnt/ML/train.csv')
test_data = pd.read_csv(r'/mnt/ML/testA.csv')

train_get_feature = [k.split(',') for k in train_data.heartbeat_signals]
test_get_feature = [k.split(',') for k in test_data.heartbeat_signals]

train_feature = pd.DataFrame(train_get_feature)
train_feature = train_feature.astype(float)

test_feature = pd.DataFrame(test_get_feature)
test_feature = test_feature.astype(float)
X_train, X_validation, Y_train, Y_validation = train_test_split(train_feature, train_data.label, test_size=0.2,random_state=42)

train_X = np.array(X_train)
train_Y = np.array(Y_train)
X_validation = np.array(X_validation)
Y_validation = np.array(Y_validation)


train_X = train_X.reshape(train_X.shape[0], train_X.shape[1], 1)
X_validation = X_validation.reshape(X_validation.shape[0], X_validation.shape[1], 1)
# Out:
# Using TensorFlow backend.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=(8,), padding='same',
                           activation=tf.keras.layers.LeakyReLU(alpha=0.001), input_shape=(train_X.shape[1], 1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool1D(pool_size=(4,), strides=2, padding='same'),

    tf.keras.layers.Conv1D(filters=64, kernel_size=(8,), padding='same',
                           activation=tf.keras.layers.LeakyReLU(alpha=0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool1D(pool_size=(4,), strides=2, padding='same'),
    
    tf.keras.layers.Conv1D(filters=128, kernel_size=(6,), padding='same',
                           activation=tf.keras.layers.LeakyReLU(alpha=0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool1D(pool_size=(3,), strides=2, padding='same'),

    tf.keras.layers.Conv1D(filters=128, kernel_size=(4,), padding='same',
                           activation=tf.keras.layers.LeakyReLU(alpha=0.001)), 
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool1D(pool_size=(3,), strides=1, padding='same'),
                           
    tf.keras.layers.Conv1D(filters=256, kernel_size=(3,), padding='same',
                           activation=tf.keras.layers.LeakyReLU(alpha=0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool1D(pool_size=(3,), strides=1, padding='same'),
    
    tf.keras.layers.Conv1D(filters=256, kernel_size=(3,), padding='same',
                           activation=tf.keras.layers.LeakyReLU(alpha=0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool1D(pool_size=(3,), strides=1, padding='same'),

    tf.keras.layers.Conv1D(filters=512, kernel_size=(2,), padding='same',
                           activation=tf.keras.layers.LeakyReLU(alpha=0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool1D(pool_size=(2,), strides=1, padding='same'),
    
    tf.keras.layers.Conv1D(filters=512, kernel_size=(2,), padding='same',
                           activation=tf.keras.layers.LeakyReLU(alpha=0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool1D(pool_size=(2,), strides=1, padding='same'),

    
    tf.keras.layers.GlobalAveragePooling1D(),
#     tf.keras.layers.Dropout(0.5), 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation=tf.keras.layers.LeakyReLU(alpha=0.001)),
#     tf.keras.layers.Dense(units=512, activation=tf.keras.layers.LeakyReLU(alpha=0.001)),
#     tf.keras.layers.Dropout(0.5), 
    tf.keras.layers.Dense(units=4, activation='softmax')
])


model.summary()
opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, decay=1e-6, nesterov=False)

# opt=tf.keras.optimizers.Adam(
#     learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
#     name='Adam'
# )
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

num_epochs = 64
cnn=model.fit(train_X,
          train_Y,
          batch_size=64,
          epochs=num_epochs,
          validation_data=(X_validation,Y_validation),
          verbose=2)


def abs_sum(y_tru, y_pre):
    y_tru = pd.get_dummies(data=y_tru)
    y_pre = np.array(y_pre)
    y_tru = np.array(y_tru)
    loss = sum(sum(abs(y_pre - y_tru)))
    return loss


pre = model.predict(X_validation)
print(abs_sum(Y_validation, pre))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 205, 64)           576
# _________________________________________________________________
# batch_normalization (BatchNo (None, 205, 64)           256
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 103, 64)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 103, 64)           32832
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 103, 64)           256
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 52, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 52, 128)           49280
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 52, 128)           512
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 26, 128)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 26, 128)           65664
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 26, 128)           512
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 26, 128)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 26, 256)           98560
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 26, 256)           1024
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 26, 256)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 26, 256)           196864
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 26, 256)           1024
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 26, 256)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 26, 512)           262656
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 26, 512)           2048
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 26, 512)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 26, 512)           524800
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 26, 512)           2048
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 26, 512)           0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 512)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,503,620
# Trainable params: 1,499,780
# Non-trainable params: 3,840
# _________________________________________________________________
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/64
# 80000/80000 - 25s - loss: 0.1210 - accuracy: 0.9621 - val_loss: 0.0608 - val_accuracy: 0.9804
# Epoch 2/64
# 80000/80000 - 18s - loss: 0.0565 - accuracy: 0.9819 - val_loss: 0.0565 - val_accuracy: 0.9826
# Epoch 3/64
# 80000/80000 - 18s - loss: 0.0428 - accuracy: 0.9862 - val_loss: 0.0424 - val_accuracy: 0.9875
# Epoch 4/64
# 80000/80000 - 18s - loss: 0.0331 - accuracy: 0.9890 - val_loss: 0.0440 - val_accuracy: 0.9862
# Epoch 5/64
# 80000/80000 - 18s - loss: 0.0282 - accuracy: 0.9903 - val_loss: 0.0470 - val_accuracy: 0.9848
# Epoch 6/64
# 80000/80000 - 18s - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.0490 - val_accuracy: 0.9841
# Epoch 7/64
# 80000/80000 - 18s - loss: 0.0215 - accuracy: 0.9927 - val_loss: 0.0337 - val_accuracy: 0.9897
# Epoch 8/64
# 80000/80000 - 18s - loss: 0.0188 - accuracy: 0.9935 - val_loss: 0.0351 - val_accuracy: 0.9893
# Epoch 9/64
# 80000/80000 - 18s - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.0320 - val_accuracy: 0.9906
# Epoch 10/64
# 80000/80000 - 18s - loss: 0.0135 - accuracy: 0.9952 - val_loss: 0.0335 - val_accuracy: 0.9893
# Epoch 11/64
# 80000/80000 - 18s - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0327 - val_accuracy: 0.9901
# Epoch 12/64
# 80000/80000 - 18s - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0328 - val_accuracy: 0.9910
# Epoch 13/64
# 80000/80000 - 18s - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0338 - val_accuracy: 0.9901
# Epoch 14/64
# 80000/80000 - 18s - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0254 - val_accuracy: 0.9931
# Epoch 15/64
# 80000/80000 - 18s - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0371 - val_accuracy: 0.9899
# Epoch 16/64
# 80000/80000 - 18s - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0250 - val_accuracy: 0.9930
# Epoch 17/64
# 80000/80000 - 18s - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0261 - val_accuracy: 0.9933
# Epoch 18/64
# 80000/80000 - 18s - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0337 - val_accuracy: 0.9916
# Epoch 19/64
# 80000/80000 - 18s - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0266 - val_accuracy: 0.9923
# Epoch 20/64
# 80000/80000 - 18s - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0329 - val_accuracy: 0.9917
# Epoch 21/64
# 80000/80000 - 18s - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0267 - val_accuracy: 0.9932
# Epoch 22/64
# 80000/80000 - 18s - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0298 - val_accuracy: 0.9924
# Epoch 23/64
# 80000/80000 - 18s - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0274 - val_accuracy: 0.9927
# Epoch 24/64
# 80000/80000 - 18s - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0252 - val_accuracy: 0.9945
# Epoch 25/64
# 80000/80000 - 18s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0242 - val_accuracy: 0.9940
# Epoch 26/64
# 80000/80000 - 18s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0251 - val_accuracy: 0.9940
# Epoch 27/64
# 80000/80000 - 18s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0265 - val_accuracy: 0.9938
# Epoch 28/64
# 80000/80000 - 18s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0251 - val_accuracy: 0.9941
# Epoch 29/64
# 80000/80000 - 18s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0264 - val_accuracy: 0.9944
# Epoch 30/64
# 80000/80000 - 18s - loss: 6.3057e-04 - accuracy: 0.9998 - val_loss: 0.0245 - val_accuracy: 0.9949
# Epoch 31/64
# 80000/80000 - 18s - loss: 3.8435e-04 - accuracy: 0.9999 - val_loss: 0.0254 - val_accuracy: 0.9944
# Epoch 32/64
# 80000/80000 - 18s - loss: 7.1511e-04 - accuracy: 0.9998 - val_loss: 0.0258 - val_accuracy: 0.9948
# Epoch 33/64
# 80000/80000 - 18s - loss: 3.5795e-04 - accuracy: 0.9999 - val_loss: 0.0266 - val_accuracy: 0.9943
# Epoch 34/64
# 80000/80000 - 18s - loss: 5.2937e-04 - accuracy: 0.9998 - val_loss: 0.0264 - val_accuracy: 0.9948
# Epoch 35/64
# 80000/80000 - 18s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0247 - val_accuracy: 0.9941
# Epoch 36/64
# 80000/80000 - 18s - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0321 - val_accuracy: 0.9934
# Epoch 37/64
# 80000/80000 - 18s - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0288 - val_accuracy: 0.9940
# Epoch 38/64
# 80000/80000 - 18s - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0341 - val_accuracy: 0.9923
# Epoch 39/64
# 80000/80000 - 18s - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0278 - val_accuracy: 0.9935
# Epoch 40/64
# 80000/80000 - 18s - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0279 - val_accuracy: 0.9934
# Epoch 41/64
# 80000/80000 - 18s - loss: 9.1043e-04 - accuracy: 0.9997 - val_loss: 0.0260 - val_accuracy: 0.9944
# Epoch 42/64
# 80000/80000 - 18s - loss: 5.4840e-04 - accuracy: 0.9999 - val_loss: 0.0249 - val_accuracy: 0.9944
# Epoch 43/64
# 80000/80000 - 18s - loss: 8.3458e-04 - accuracy: 0.9998 - val_loss: 0.0268 - val_accuracy: 0.9943
# Epoch 44/64
# 80000/80000 - 18s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0305 - val_accuracy: 0.9936
# Epoch 45/64
# 80000/80000 - 18s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0246 - val_accuracy: 0.9944
# Epoch 46/64
# 80000/80000 - 18s - loss: 7.4924e-04 - accuracy: 0.9998 - val_loss: 0.0315 - val_accuracy: 0.9940
# Epoch 47/64
# 80000/80000 - 18s - loss: 8.0148e-04 - accuracy: 0.9998 - val_loss: 0.0262 - val_accuracy: 0.9945
# Epoch 48/64
# 80000/80000 - 18s - loss: 9.2765e-04 - accuracy: 0.9997 - val_loss: 0.0320 - val_accuracy: 0.9938
# Epoch 49/64
# 80000/80000 - 18s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0395 - val_accuracy: 0.9915
# Epoch 50/64
# 80000/80000 - 18s - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0263 - val_accuracy: 0.9950
# Epoch 51/64
# 80000/80000 - 18s - loss: 5.4074e-04 - accuracy: 0.9999 - val_loss: 0.0262 - val_accuracy: 0.9948
# Epoch 52/64
# 80000/80000 - 18s - loss: 2.1774e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9949
# Epoch 53/64
# 80000/80000 - 18s - loss: 9.5637e-05 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9951
# Epoch 54/64
# 80000/80000 - 18s - loss: 6.8579e-05 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9950
# Epoch 55/64
# 80000/80000 - 18s - loss: 8.9023e-05 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9952
# Epoch 56/64
# 80000/80000 - 18s - loss: 6.4127e-05 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9951
# Epoch 57/64
# 80000/80000 - 18s - loss: 4.9492e-05 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9951
# Epoch 58/64
# 80000/80000 - 18s - loss: 3.9279e-05 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9949
# Epoch 59/64
# 80000/80000 - 18s - loss: 2.9458e-05 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9951
# Epoch 60/64
# 80000/80000 - 18s - loss: 2.8820e-05 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9952
# Epoch 61/64
# 80000/80000 - 18s - loss: 3.3333e-05 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9951
# Epoch 62/64
# 80000/80000 - 18s - loss: 2.9222e-05 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9952
# Epoch 63/64
# 80000/80000 - 18s - loss: 2.5600e-05 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9951
# Epoch 64/64
# 80000/80000 - 18s - loss: 2.5833e-05 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9951
# 212.77232933044434

# %%
pre2=pre.copy()
for i in range(len(pre2)):
    for j in range(len(pre2[0])):
        pre2[i][j]=int(pre2[i][j]+0.5)
        
print(abs_sum(Y_validation, pre2))
# Out:
# 197.0

# %%
test_feature = pd.DataFrame(test_get_feature)
test_feature = test_feature.astype(float)
test_X = np.array(test_feature)
test_X = test_X.reshape(test_X.shape[0], test_X.shape[1], 1)
pre = model.predict(test_X)
data_test_price = pd.DataFrame(pre,columns = ['label_0','label_1','label_2','label_3'])
results = pd.concat([test_data['id'],data_test_price],axis = 1)
submit_file_z_score = r'/mnt/ML/cnn_A1_212.csv'
results.to_csv(submit_file_z_score,encoding='utf8',index=0)

test_data1 = pd.read_csv(r'/mnt/ML/testB.csv')

test_data1.heartbeat_signals

test_get_feature1 = [k.split(',') for k in test_data1.heartbeat_signals]



test_feature1 = pd.DataFrame(test_get_feature1)
test_feature1 = test_feature1.astype(float)
test_X1 = np.array(test_feature1)
test_X1 = test_X1.reshape(test_X1.shape[0], test_X1.shape[1], 1)
pre1 = model.predict(test_X1)

data_test_price1 = pd.DataFrame(pre1,columns = ['label_0','label_1','label_2','label_3'])
results1 = pd.concat([test_data1['id'],data_test_price1],axis = 1)
submit_file_z_score1 = r'/mnt/ML/cnn_B1_212.csv'
results1.to_csv(submit_file_z_score1,encoding='utf8',index=0)

# %%
model.save('cnn_conv10_212', save_format='tf')
# Out:
# WARNING:tensorflow:From /root/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: cnn_conv10_212/assets
