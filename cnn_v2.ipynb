# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers,activations
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)


import tensorflow as tf
from keras.utils import np_utils

train_data = pd.read_csv(r'/mnt/ML/train.csv')
test_data = pd.read_csv(r'/mnt/ML/testA.csv')

train_get_feature = [k.split(',') for k in train_data.heartbeat_signals]
test_get_feature = [k.split(',') for k in test_data.heartbeat_signals]

train_feature = pd.DataFrame(train_get_feature)
train_feature = train_feature.astype(float)

test_feature = pd.DataFrame(test_get_feature)
test_feature = test_feature.astype(float)
# Out:
# Using TensorFlow backend.

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(train_feature, train_data.label, test_size=0.2,random_state=42)

train_X = np.array(X_train)
train_Y = np.array(Y_train)
X_validation = np.array(X_validation)
Y_validation = np.array(Y_validation)

train_X = train_X.reshape(train_X.shape[0], train_X.shape[1], 1)
X_validation = X_validation.reshape(X_validation.shape[0], X_validation.shape[1], 1)

# %%
class Residual(tf.keras.Model):
    def __init__(self, num_channels,kernel_size, use_1x1conv=False, strides=1, **kwargs):
        super(Residual, self).__init__(**kwargs)
        self.conv1 = layers.Conv1D(num_channels,
                                   padding='same',
                                   kernel_size=kernel_size,
                                   strides=strides)
        self.conv2 = layers.Conv1D(num_channels, kernel_size=kernel_size,padding='same')
        if use_1x1conv:
            self.conv3 = layers.Conv1D(num_channels,
                                       kernel_size=1,
                                       strides=strides)
        else:
            self.conv3 = None
        self.bn1 = layers.BatchNormalization()
        self.bn2 = layers.BatchNormalization()

    def call(self, X):
        Y = activations.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))
        if self.conv3:
            X = self.conv3(X)
        return activations.relu(Y + X)


class ResnetBlock(tf.keras.layers.Layer):
    def __init__(self,num_channels,kernel_size, num_residuals, first_block=False,**kwargs):
        super(ResnetBlock, self).__init__(**kwargs)
        self.listLayers=[]
        for i in range(num_residuals):
            if i == 0 and not first_block:
                self.listLayers.append(Residual(num_channels,kernel_size, use_1x1conv=True, strides=2))
            else:
                self.listLayers.append(Residual(num_channels,kernel_size))      

    def call(self, X):
        for layer in self.listLayers.layers:
            X = layer(X)
        return X


class ResNet(tf.keras.Model):
    def __init__(self,num_blocks,**kwargs):
        super(ResNet, self).__init__(**kwargs)
        self.conv=layers.Conv1D(64, kernel_size=5, padding='same')
        self.bn=layers.BatchNormalization()
        self.relu=layers.LeakyReLU(alpha=0.001)
        self.mp=layers.MaxPool1D(pool_size=5, strides=2, padding='same')
        self.resnet_block1=ResnetBlock(64,8,num_blocks[0], first_block=True)
        self.resnet_block2=ResnetBlock(128,6,num_blocks[1])
        self.resnet_block3=ResnetBlock(256,4,num_blocks[2])
        self.resnet_block4=ResnetBlock(512,2,num_blocks[3])
        self.gap=layers.GlobalAvgPool1D()
        self.fc=layers.Dense(units=4,activation=activations.softmax)

    def call(self, x):
        x=self.conv(x)
        x=self.bn(x)
        x=self.relu(x)
        x=self.mp(x)
        x=self.resnet_block1(x)
        x=self.resnet_block2(x)
        x=self.resnet_block3(x)
        x=self.resnet_block4(x)
        x=self.gap(x)
        x=self.fc(x)
        return x


def build_resnet(keyword = 'resnet34'):
    if keyword == 'resnet34':
        return ResNet([3,4,6,3])
    if keyword == 'resnet18':
        return ResNet([2,2,2,2])

# %%
def train_resnet(batch_size, epoch):
    # build model
    net =build_resnet('resnet34')  # resnet20 resnet34
    
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, decay=1e-6, nesterov=False)
#     optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, decay=1e-6)
    
    net.compile(optimizer=optimizer ,loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    net.fit(train_X,
            train_Y,
            epochs=epoch,
            verbose=2,
            validation_data=(X_validation,Y_validation),
            batch_size=batch_size, 
            shuffle=True)
    return net

model_cnn=train_resnet(64,60)
print(model_cnn.summary())
# X_new_train = model_cnn.predict(train_X)
# Y_new_train=train_Y.copy()
# X_new_test = model_cnn.predict(X_validation)
# Y_new_test=Y_validation.copy()

#output 直接分类
def abs_sum(y_tru, y_pre):
    y_tru = pd.get_dummies(data=y_tru)
    y_pre = np.array(y_pre)
    y_tru = np.array(y_tru)
    loss = sum(sum(abs(y_pre - y_tru)))
    return loss


pre = model_cnn.predict(X_validation)
copy_test=pre.copy()
for i in range(len(copy_test)):
    for j in range(len(copy_test[0])):
        copy_test[i][j]=int(copy_test[i][j]+0.5)

print(abs_sum(Y_validation, pre))
print(abs_sum(Y_validation, copy_test))
# Out:
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in <lambda>(self, name, value)
#    1347     __swig_setmethods__ = {}
# -> 1348     __setattr__ = lambda self, name, value: _swig_setattr(self, TF_Buffer, name, value)
#    1349     __swig_getmethods__ = {}
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in _swig_setattr(self, class_type, name, value)
#      58 def _swig_setattr(self, class_type, name, value):
# ---> 59     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#      60
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/pywrap_tensorflow_internal.py in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      42     if (name == "this"):
# ---> 43         if type(value).__name__ == 'SwigPyObject':
#      44             self.__dict__[name] = value
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-4-4a00ad97ccf8> in <module>
#      16     return net
#      17
# ---> 18 model_cnn=train_resnet(64,60)
#      19 print(model_cnn.summary())
#      20 # X_new_train = model_cnn.predict(train_X)
#
# <ipython-input-4-4a00ad97ccf8> in train_resnet(batch_size, epoch)
#      13             validation_data=(X_validation,Y_validation),
#      14             batch_size=batch_size,
# ---> 15             shuffle=True)
#      16     return net
#      17
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     501       # This is the first call of __call__, so we have to initialize.
#     502       initializer_map = object_identity.ObjectIdentityDictionary()
# --> 503       self._initialize(args, kwds, add_initializers_to=initializer_map)
#     504     finally:
#     505       # At this point we know that the initialization is complete (or less
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     406     self._concrete_stateful_fn = (
#     407         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 408             *args, **kwds))
#     409
#     410     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    1846     if self.input_signature:
#    1847       args, kwargs = None, None
# -> 1848     graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    1849     return graph_function
#    1850
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2148         graph_function = self._function_cache.primary.get(cache_key, None)
#    2149         if graph_function is None:
# -> 2150           graph_function = self._create_graph_function(args, kwargs)
#    2151           self._function_cache.primary[cache_key] = graph_function
#    2152         return graph_function, args, kwargs
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2039             arg_names=arg_names,
#    2040             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2041             capture_by_value=self._capture_by_value),
#    2042         self._function_attributes,
#    2043         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     913                                           converted_func)
#     914
# --> 915       func_outputs = python_func(*func_args, **func_kwargs)
#     916
#     917       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     356         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     357         # the function a weak reference to itself to avoid a reference cycle.
# --> 358         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     359     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     360
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in distributed_function(input_iterator)
#      71     strategy = distribution_strategy_context.get_strategy()
#      72     outputs = strategy.experimental_run_v2(
# ---> 73         per_replica_function, args=(model, x, y, sample_weights))
#      74     # Out of PerReplica outputs reduce or pick values to return.
#      75     all_outputs = dist_utils.unwrap_output_dict(
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/distribute/distribute_lib.py in experimental_run_v2(self, fn, args, kwargs)
#     758       fn = autograph.tf_convert(fn, ag_ctx.control_status_ctx(),
#     759                                 convert_by_default=False)
# --> 760       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     761
#     762   def reduce(self, reduce_op, value, axis):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    1785       kwargs = {}
#    1786     with self._container_strategy().scope():
# -> 1787       return self._call_for_each_replica(fn, args, kwargs)
#    1788
#    1789   def _call_for_each_replica(self, fn, args, kwargs):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    2130         self._container_strategy(),
#    2131         replica_id_in_sync_group=constant_op.constant(0, dtypes.int32)):
# -> 2132       return fn(*args, **kwargs)
#    2133
#    2134   def _reduce_to(self, reduce_op, value, destinations):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     290   def wrapper(*args, **kwargs):
#     291     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 292       return func(*args, **kwargs)
#     293
#     294   if inspect.isfunction(func) or inspect.ismethod(func):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     270                         loss_scale_optimizer.LossScaleOptimizer):
#     271             grads = model.optimizer.get_unscaled_gradients(grads)
# --> 272           model.optimizer.apply_gradients(zip(grads, trainable_weights))
#     273       else:
#     274         logging.warning('The list of trainable weights is empty. Make sure that'
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name)
#     439           functools.partial(self._distributed_apply, apply_state=apply_state),
#     440           args=(grads_and_vars,),
# --> 441           kwargs={"name": name})
#     442
#     443   def _distributed_apply(self, distribution, grads_and_vars, name, apply_state):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/distribute/distribute_lib.py in merge_call(self, merge_fn, args, kwargs)
#    1915     if kwargs is None:
#    1916       kwargs = {}
# -> 1917     return self._merge_call(merge_fn, args, kwargs)
#    1918
#    1919   def _merge_call(self, merge_fn, args, kwargs):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/distribute/distribute_lib.py in _merge_call(self, merge_fn, args, kwargs)
#    1922         distribution_strategy_context._CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    1923     try:
# -> 1924       return merge_fn(self._strategy, *args, **kwargs)
#    1925     finally:
#    1926       _pop_per_thread_mode()
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in _distributed_apply(self, distribution, grads_and_vars, name, apply_state)
#     483           update_ops.extend(
#     484               distribution.extended.update(
# --> 485                   var, apply_grad_to_update_var, args=(grad,), group=False))
#     486
#     487       any_symbolic = any(isinstance(i, ops.Operation) or
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/distribute/distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    1528       kwargs = {}
#    1529     with self._container_strategy().scope():
# -> 1530       return self._update(var, fn, args, kwargs, group)
#    1531
#    1532   def _update(self, var, fn, args, kwargs, group):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/distribute/distribute_lib.py in _update(self, var, fn, args, kwargs, group)
#    2140     # The implementations of _update() and _update_non_slot() are identical
#    2141     # except _update() passes `var` as the first argument to `fn()`.
# -> 2142     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#    2143
#    2144   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/distribute/distribute_lib.py in _update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    2146     # once that value is used for something.
#    2147     with UpdateContext(colocate_with):
# -> 2148       result = fn(*args, **kwargs)
#    2149       if should_group:
#    2150         return result
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/optimizer_v2/optimizer_v2.py in apply_grad_to_update_var(var, grad)
#     465       if "apply_state" in self._dense_apply_args:
#     466         apply_kwargs["apply_state"] = apply_state
# --> 467       update_op = self._resource_apply_dense(grad, var, **apply_kwargs)
#     468       if var.constraint is not None:
#     469         with ops.control_dependencies([update_op]):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/keras/optimizer_v2/gradient_descent.py in _resource_apply_dense(self, grad, var, apply_state)
#     119           coefficients["momentum"],
#     120           use_locking=self._use_locking,
# --> 121           use_nesterov=self.nesterov)
#     122     else:
#     123       return training_ops.resource_apply_gradient_descent(
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/training/gen_training_ops.py in resource_apply_keras_momentum(var, accum, lr, grad, momentum, use_locking, use_nesterov, name)
#    2212                                       momentum=momentum,
#    2213                                       use_locking=use_locking,
# -> 2214                                       use_nesterov=use_nesterov, name=name)
#    2215   return _op
#    2216   _result = None
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     525                 dtype=dtype,
#     526                 as_ref=input_arg.is_ref,
# --> 527                 preferred_dtype=default_dtype)
#     528           except TypeError as err:
#     529             if dtype is None:
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accept_composite_tensors)
#    1264       raise RuntimeError("Attempting to capture an EagerTensor without "
#    1265                          "building a function.")
# -> 1266     return graph.capture(value, name=name)
#    1267   elif isinstance(value, Tensor):
#    1268     if dtype is not None and not dtype.is_compatible_with(value.dtype):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/func_graph.py in capture(self, tensor, name)
#     589
#     590       # Large EagerTensors and resources are captured with Placeholder ops
# --> 591       return self._capture_helper(tensor, name)
#     592     if tensor.graph is not self:
#     593       if name is None:
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/func_graph.py in _capture_helper(self, tensor, name)
#     610     if capture is None:
#     611       placeholder = _create_substitute_placeholder(
# --> 612           tensor, name=name, dtype=tensor.dtype)
#     613       self.add_capture(tensor, placeholder)
#     614     else:
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/func_graph.py in _create_substitute_placeholder(value, name, dtype)
#    1052   with ops.control_dependencies(None):
#    1053     placeholder = graph_placeholder(
# -> 1054         dtype=dtype or value.dtype, shape=value.shape, name=name)
#    1055   custom_gradient.copy_handle_data(value, placeholder)
#    1056   return placeholder
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/eager/graph_only_ops.py in graph_placeholder(dtype, shape, name)
#      49   with ops.name_scope(name, "placeholder", []) as name:
#      50     op = g.create_op("Placeholder", [], [dtype], input_types=[],
# ---> 51                      attrs={"dtype": dtype_value, "shape": shape}, name=name)
#      52   result, = op.outputs
#      53   return result
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/func_graph.py in create_op(***failed resolving arguments***)
#     546     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     547         op_type, inputs, dtypes, input_types, name, attrs, op_def,
# --> 548         compute_device)
#     549
#     550   def capture(self, tensor, name=None):
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3428           original_op=self._default_original_op,
#    3429           op_def=op_def)
# -> 3430       self._create_op_helper(ret, compute_device=compute_device)
#    3431     return ret
#    3432
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in _create_op_helper(self, op, compute_device)
#    3513       all_colocation_groups = []
#    3514       for colocation_op in self._colocation_stack.peek_objs():
# -> 3515         all_colocation_groups.extend(colocation_op.colocation_groups())
#    3516         if colocation_op.device:
#    3517           # pylint: disable=protected-access
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in colocation_groups(self)
#    1842     default_colocation_group = [compat.as_bytes("loc:@%s" % self.name)]
#    1843     try:
# -> 1844       class_attr = self.get_attr("_class")
#    1845     except ValueError:
#    1846       # This op has no explicit colocation group, so it is itself its
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in get_attr(self, name)
#    2380     fields = ("s", "i", "f", "b", "type", "shape", "tensor", "func")
#    2381     try:
# -> 2382       with c_api_util.tf_buffer() as buf:
#    2383         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2384         data = c_api.TF_GetBuffer(buf)
#
# ~/miniconda3/envs/myconda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/miniconda3/envs/myconda/lib/python3.7/site-packages/tensorflow_core/python/framework/c_api_util.py in tf_buffer(data)
#     167     buf = c_api.TF_NewBufferFromString(compat.as_bytes(data))
#     168   else:
# --> 169     buf = c_api.TF_NewBuffer()
#     170   try:
#     171     yield buf
#
# SystemError: <built-in function TF_NewBuffer> returned a result with an error set

# %%
test_feature = pd.DataFrame(test_get_feature)
test_feature = test_feature.astype(float)
test_X = np.array(test_feature)
test_X = test_X.reshape(test_X.shape[0], test_X.shape[1], 1)
pre = model_cnn.predict(test_X)
data_test_price = pd.DataFrame(pre,columns = ['label_0','label_1','label_2','label_3'])
results = pd.concat([test_data['id'],data_test_price],axis = 1)
submit_file_z_score = r'/mnt/ML/resnet_A1_230.95916.csv'
results.to_csv(submit_file_z_score,encoding='utf8',index=0)

test_data1 = pd.read_csv(r'/mnt/ML/testB.csv')

test_data1.heartbeat_signals

test_get_feature1 = [k.split(',') for k in test_data1.heartbeat_signals]


test_feature1 = pd.DataFrame(test_get_feature1)
test_feature1 = test_feature1.astype(float)
test_X1 = np.array(test_feature1)
test_X1 = test_X1.reshape(test_X1.shape[0], test_X1.shape[1], 1)
pre1 = model_cnn.predict(test_X1)

data_test_price1 = pd.DataFrame(pre1,columns = ['label_0','label_1','label_2','label_3'])
results1 = pd.concat([test_data1['id'],data_test_price1],axis = 1)
submit_file_z_score1 = r'/mnt/ML/resnet_B1_230.95916.csv'
results1.to_csv(submit_file_z_score1,encoding='utf8',index=0)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
# 单模函数
def build_model_rf(X_train,y_train):
    model = RandomForestRegressor(n_estimators = 300,max_depth=10)
    model.fit(X_train, y_train)
    return model

def build_model_lgb(X_train,y_train):
    model = lgb.LGBMClassifier(boosting_type='gbdt', objective='multiclass', num_class=4,
                               learning_rate=0.01, n_estimators=500,
                               num_leaves=138, max_depth=11, 
                               bagging_fraction=0.64, 
                               feature_fraction=0.93,
                               bagging_freq=49, 
                               min_split_gain=0.288,
                               min_child_weight=6.5,
                               reg_alpha=0.21,
                               reg_lambda=7)
    model.fit(X_train, y_train)
    return model

def build_model_xgb(X_train,y_train):
    param_dist = {'objective':'multi:softmax', 'n_estimators':600, 'max_depth':6, 'use_label_encoder':False,'num_class':4,'early_stopping_rounds':50}
    model = XGBClassifier(**param_dist)
    model.fit(X_train, y_train, eval_set=[(X_train,y_train)], eval_metric='mlogloss')
    return model

# %%
# pd.DataFrame(X_new_train).to_csv('x_new_train.csv')
# pd.DataFrame(Y_new_train).to_csv('y_new_train.csv')
# pd.DataFrame(X_new_test).to_csv('x_new_test.csv')
# pd.DataFrame(Y_new_test).to_csv('y_new_test.csv')

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
# X_new_train=pd.read_csv('x_new_train.csv')
# Y_new_train=pd.read_csv('y_new_train.csv',names={'label','id'})
# X_new_test=pd.read_csv('x_new_test.csv')
# Y_new_test=pd.read_csv('y_new_test.csv')

# print('predict rf...')
# model_rf = build_model_rf(X_new_train,Y_new_train)
# train_rf = model_rf.predict(X_new_train)
# test_rf = model_rf.predict(X_new_test)


print('predict lgb...')
model_lgb = build_model_lgb(X_new_train,Y_new_train)
train_lgb = model_lgb.predict(X_new_train)
test_lgb = model_lgb.predict(X_new_test)


print('predict xgb...')
model_xgb = build_model_xgb(X_new_train,Y_new_train)
train_xgb = model_xgb.predict(X_new_train)
test_xgb = model_xgb.predict(X_new_test)
# Out:
# predict lgb...
# predict xgb...
# [0]	validation_0-mlogloss:0.85359
# [1]	validation_0-mlogloss:0.58081
# [2]	validation_0-mlogloss:0.40892
# [3]	validation_0-mlogloss:0.29300
# [4]	validation_0-mlogloss:0.21217
# [5]	validation_0-mlogloss:0.15469
# [6]	validation_0-mlogloss:0.11330
# [7]	validation_0-mlogloss:0.08324
# [8]	validation_0-mlogloss:0.06131
# [9]	validation_0-mlogloss:0.04522
# [10]	validation_0-mlogloss:0.03340
# [11]	validation_0-mlogloss:0.02469
# [12]	validation_0-mlogloss:0.01827
# [13]	validation_0-mlogloss:0.01352
# [14]	validation_0-mlogloss:0.01001
# [15]	validation_0-mlogloss:0.00742
# [16]	validation_0-mlogloss:0.00550
# [17]	validation_0-mlogloss:0.00408
# [18]	validation_0-mlogloss:0.00302
# [19]	validation_0-mlogloss:0.00225
# [20]	validation_0-mlogloss:0.00167
# [21]	validation_0-mlogloss:0.00124
# [22]	validation_0-mlogloss:0.00093
# [23]	validation_0-mlogloss:0.00069
# [24]	validation_0-mlogloss:0.00052
# [25]	validation_0-mlogloss:0.00039
# [26]	validation_0-mlogloss:0.00029
# [27]	validation_0-mlogloss:0.00022
# [28]	validation_0-mlogloss:0.00017
# [29]	validation_0-mlogloss:0.00013
# [30]	validation_0-mlogloss:0.00010
# [31]	validation_0-mlogloss:0.00008
# [32]	validation_0-mlogloss:0.00006
# [33]	validation_0-mlogloss:0.00005
# [34]	validation_0-mlogloss:0.00004
# [35]	validation_0-mlogloss:0.00003
# [36]	validation_0-mlogloss:0.00003
# [37]	validation_0-mlogloss:0.00003
# [38]	validation_0-mlogloss:0.00003
# [39]	validation_0-mlogloss:0.00002
# [40]	validation_0-mlogloss:0.00002
# [41]	validation_0-mlogloss:0.00002
# [42]	validation_0-mlogloss:0.00002
# [43]	validation_0-mlogloss:0.00002
# [44]	validation_0-mlogloss:0.00002
# [45]	validation_0-mlogloss:0.00002
# [46]	validation_0-mlogloss:0.00002
# [47]	validation_0-mlogloss:0.00002
# [48]	validation_0-mlogloss:0.00002
# [49]	validation_0-mlogloss:0.00002
# [50]	validation_0-mlogloss:0.00002
# [51]	validation_0-mlogloss:0.00002
# [52]	validation_0-mlogloss:0.00002
# [53]	validation_0-mlogloss:0.00002
# [54]	validation_0-mlogloss:0.00002
# [55]	validation_0-mlogloss:0.00002
# [56]	validation_0-mlogloss:0.00002
# [57]	validation_0-mlogloss:0.00002
# [58]	validation_0-mlogloss:0.00002
# [59]	validation_0-mlogloss:0.00002
# [60]	validation_0-mlogloss:0.00002
# [61]	validation_0-mlogloss:0.00002
# [62]	validation_0-mlogloss:0.00002
# [63]	validation_0-mlogloss:0.00002
# [64]	validation_0-mlogloss:0.00002
# [65]	validation_0-mlogloss:0.00002
# [66]	validation_0-mlogloss:0.00002
# [67]	validation_0-mlogloss:0.00002
# [68]	validation_0-mlogloss:0.00002
# [69]	validation_0-mlogloss:0.00002
# [70]	validation_0-mlogloss:0.00002
# [71]	validation_0-mlogloss:0.00002
# [72]	validation_0-mlogloss:0.00002
# [73]	validation_0-mlogloss:0.00002
# [74]	validation_0-mlogloss:0.00002
# [75]	validation_0-mlogloss:0.00002
# [76]	validation_0-mlogloss:0.00002
# [77]	validation_0-mlogloss:0.00002
# [78]	validation_0-mlogloss:0.00002
# [79]	validation_0-mlogloss:0.00002
# [80]	validation_0-mlogloss:0.00002
# [81]	validation_0-mlogloss:0.00002
# [82]	validation_0-mlogloss:0.00002
# [83]	validation_0-mlogloss:0.00002
# [84]	validation_0-mlogloss:0.00002
# [85]	validation_0-mlogloss:0.00002
# [86]	validation_0-mlogloss:0.00002
# [87]	validation_0-mlogloss:0.00002
# [88]	validation_0-mlogloss:0.00002
# [89]	validation_0-mlogloss:0.00002
# [90]	validation_0-mlogloss:0.00002
# [91]	validation_0-mlogloss:0.00002
# [92]	validation_0-mlogloss:0.00002
# [93]	validation_0-mlogloss:0.00002
# [94]	validation_0-mlogloss:0.00002
# [95]	validation_0-mlogloss:0.00002
# [96]	validation_0-mlogloss:0.00002
# [97]	validation_0-mlogloss:0.00002
# [98]	validation_0-mlogloss:0.00002
# [99]	validation_0-mlogloss:0.00002
# [100]	validation_0-mlogloss:0.00002
# [101]	validation_0-mlogloss:0.00002
# [102]	validation_0-mlogloss:0.00002
# [103]	validation_0-mlogloss:0.00002
# [104]	validation_0-mlogloss:0.00002
# [105]	validation_0-mlogloss:0.00002
# [106]	validation_0-mlogloss:0.00002
# [107]	validation_0-mlogloss:0.00002
# [108]	validation_0-mlogloss:0.00002
# [109]	validation_0-mlogloss:0.00002
# [110]	validation_0-mlogloss:0.00002
# [111]	validation_0-mlogloss:0.00002
# [112]	validation_0-mlogloss:0.00002
# [113]	validation_0-mlogloss:0.00002
# [114]	validation_0-mlogloss:0.00002
# [115]	validation_0-mlogloss:0.00002
# [116]	validation_0-mlogloss:0.00002
# [117]	validation_0-mlogloss:0.00002
# [118]	validation_0-mlogloss:0.00002
# [119]	validation_0-mlogloss:0.00002
# [120]	validation_0-mlogloss:0.00002
# [121]	validation_0-mlogloss:0.00002
# [122]	validation_0-mlogloss:0.00002
# [123]	validation_0-mlogloss:0.00002
# [124]	validation_0-mlogloss:0.00002
# [125]	validation_0-mlogloss:0.00002
# [126]	validation_0-mlogloss:0.00002
# [127]	validation_0-mlogloss:0.00002
# [128]	validation_0-mlogloss:0.00002
# [129]	validation_0-mlogloss:0.00002
# [130]	validation_0-mlogloss:0.00002
# [131]	validation_0-mlogloss:0.00002
# [132]	validation_0-mlogloss:0.00002
# [133]	validation_0-mlogloss:0.00002
# [134]	validation_0-mlogloss:0.00002
# [135]	validation_0-mlogloss:0.00002
# [136]	validation_0-mlogloss:0.00002
# [137]	validation_0-mlogloss:0.00002
# [138]	validation_0-mlogloss:0.00002
# [139]	validation_0-mlogloss:0.00002
# [140]	validation_0-mlogloss:0.00002
# [141]	validation_0-mlogloss:0.00002
# [142]	validation_0-mlogloss:0.00002
# [143]	validation_0-mlogloss:0.00002
# [144]	validation_0-mlogloss:0.00002
# [145]	validation_0-mlogloss:0.00002
# [146]	validation_0-mlogloss:0.00002
# [147]	validation_0-mlogloss:0.00002
# [148]	validation_0-mlogloss:0.00002
# [149]	validation_0-mlogloss:0.00002
# [150]	validation_0-mlogloss:0.00002
# [151]	validation_0-mlogloss:0.00002
# [152]	validation_0-mlogloss:0.00002
# [153]	validation_0-mlogloss:0.00002
# [154]	validation_0-mlogloss:0.00002
# [155]	validation_0-mlogloss:0.00002
# [156]	validation_0-mlogloss:0.00002
# [157]	validation_0-mlogloss:0.00002
# [158]	validation_0-mlogloss:0.00002
# [159]	validation_0-mlogloss:0.00002
# [160]	validation_0-mlogloss:0.00002
# [161]	validation_0-mlogloss:0.00002
# [162]	validation_0-mlogloss:0.00002
# [163]	validation_0-mlogloss:0.00002
# [164]	validation_0-mlogloss:0.00002
# [165]	validation_0-mlogloss:0.00002
# [166]	validation_0-mlogloss:0.00002
# [167]	validation_0-mlogloss:0.00002
# [168]	validation_0-mlogloss:0.00002
# [169]	validation_0-mlogloss:0.00002
# [170]	validation_0-mlogloss:0.00002
# [171]	validation_0-mlogloss:0.00002
# [172]	validation_0-mlogloss:0.00002
# [173]	validation_0-mlogloss:0.00002
# [174]	validation_0-mlogloss:0.00002
# [175]	validation_0-mlogloss:0.00002
# [176]	validation_0-mlogloss:0.00002
# [177]	validation_0-mlogloss:0.00002
# [178]	validation_0-mlogloss:0.00002
# [179]	validation_0-mlogloss:0.00002
# [180]	validation_0-mlogloss:0.00002
# [181]	validation_0-mlogloss:0.00002
# [182]	validation_0-mlogloss:0.00002
# [183]	validation_0-mlogloss:0.00002
# [184]	validation_0-mlogloss:0.00002
# [185]	validation_0-mlogloss:0.00002
# [186]	validation_0-mlogloss:0.00002
# [187]	validation_0-mlogloss:0.00002
# [188]	validation_0-mlogloss:0.00002
# [189]	validation_0-mlogloss:0.00002
# [190]	validation_0-mlogloss:0.00002
# [191]	validation_0-mlogloss:0.00002
# [192]	validation_0-mlogloss:0.00002
# [193]	validation_0-mlogloss:0.00002
# [194]	validation_0-mlogloss:0.00002
# [195]	validation_0-mlogloss:0.00002
# [196]	validation_0-mlogloss:0.00002
# [197]	validation_0-mlogloss:0.00002
# [198]	validation_0-mlogloss:0.00002
# [199]	validation_0-mlogloss:0.00002
# [200]	validation_0-mlogloss:0.00002
# [201]	validation_0-mlogloss:0.00002
# [202]	validation_0-mlogloss:0.00002
# [203]	validation_0-mlogloss:0.00002
# [204]	validation_0-mlogloss:0.00002
# [205]	validation_0-mlogloss:0.00002
# [206]	validation_0-mlogloss:0.00002
# [207]	validation_0-mlogloss:0.00002
# [208]	validation_0-mlogloss:0.00002
# [209]	validation_0-mlogloss:0.00002
# [210]	validation_0-mlogloss:0.00002
# [211]	validation_0-mlogloss:0.00002
# [212]	validation_0-mlogloss:0.00002
# [213]	validation_0-mlogloss:0.00002
# [214]	validation_0-mlogloss:0.00002
# [215]	validation_0-mlogloss:0.00002
# [216]	validation_0-mlogloss:0.00002
# [217]	validation_0-mlogloss:0.00002
# [218]	validation_0-mlogloss:0.00002
# [219]	validation_0-mlogloss:0.00002
# [220]	validation_0-mlogloss:0.00002
# [221]	validation_0-mlogloss:0.00002
# [222]	validation_0-mlogloss:0.00002
# [223]	validation_0-mlogloss:0.00002
# [224]	validation_0-mlogloss:0.00002
# [225]	validation_0-mlogloss:0.00002
# [226]	validation_0-mlogloss:0.00002
# [227]	validation_0-mlogloss:0.00002
# [228]	validation_0-mlogloss:0.00002
# [229]	validation_0-mlogloss:0.00002
# [230]	validation_0-mlogloss:0.00002
# [231]	validation_0-mlogloss:0.00002
# [232]	validation_0-mlogloss:0.00002
# [233]	validation_0-mlogloss:0.00002
# [234]	validation_0-mlogloss:0.00002
# [235]	validation_0-mlogloss:0.00002
# [236]	validation_0-mlogloss:0.00002
# [237]	validation_0-mlogloss:0.00002
# [238]	validation_0-mlogloss:0.00002
# [239]	validation_0-mlogloss:0.00002
# [240]	validation_0-mlogloss:0.00002
# [241]	validation_0-mlogloss:0.00002
# [242]	validation_0-mlogloss:0.00002
# [243]	validation_0-mlogloss:0.00002
# [244]	validation_0-mlogloss:0.00002
# [245]	validation_0-mlogloss:0.00002
# [246]	validation_0-mlogloss:0.00002
# [247]	validation_0-mlogloss:0.00002
# [248]	validation_0-mlogloss:0.00002
# [249]	validation_0-mlogloss:0.00002
# [250]	validation_0-mlogloss:0.00002
# [251]	validation_0-mlogloss:0.00002
# [252]	validation_0-mlogloss:0.00002
# [253]	validation_0-mlogloss:0.00002
# [254]	validation_0-mlogloss:0.00002
# [255]	validation_0-mlogloss:0.00002
# [256]	validation_0-mlogloss:0.00002
# [257]	validation_0-mlogloss:0.00002
# [258]	validation_0-mlogloss:0.00002
# [259]	validation_0-mlogloss:0.00002
# [260]	validation_0-mlogloss:0.00002
# [261]	validation_0-mlogloss:0.00002
# [262]	validation_0-mlogloss:0.00002
# [263]	validation_0-mlogloss:0.00002
# [264]	validation_0-mlogloss:0.00002
# [265]	validation_0-mlogloss:0.00002
# [266]	validation_0-mlogloss:0.00002
# [267]	validation_0-mlogloss:0.00002
# [268]	validation_0-mlogloss:0.00002
# [269]	validation_0-mlogloss:0.00002
# [270]	validation_0-mlogloss:0.00002
# [271]	validation_0-mlogloss:0.00002
# [272]	validation_0-mlogloss:0.00002
# [273]	validation_0-mlogloss:0.00002
# [274]	validation_0-mlogloss:0.00002
# [275]	validation_0-mlogloss:0.00002
# [276]	validation_0-mlogloss:0.00002
# [277]	validation_0-mlogloss:0.00002
# [278]	validation_0-mlogloss:0.00002
# [279]	validation_0-mlogloss:0.00002
# [280]	validation_0-mlogloss:0.00002
# [281]	validation_0-mlogloss:0.00002
# [282]	validation_0-mlogloss:0.00002
# [283]	validation_0-mlogloss:0.00002
# [284]	validation_0-mlogloss:0.00002
# [285]	validation_0-mlogloss:0.00002
# [286]	validation_0-mlogloss:0.00002
# [287]	validation_0-mlogloss:0.00002
# [288]	validation_0-mlogloss:0.00002
# [289]	validation_0-mlogloss:0.00002
# [290]	validation_0-mlogloss:0.00002
# [291]	validation_0-mlogloss:0.00002
# [292]	validation_0-mlogloss:0.00002
# [293]	validation_0-mlogloss:0.00002
# [294]	validation_0-mlogloss:0.00002
# [295]	validation_0-mlogloss:0.00002
# [296]	validation_0-mlogloss:0.00002
# [297]	validation_0-mlogloss:0.00002
# [298]	validation_0-mlogloss:0.00002
# [299]	validation_0-mlogloss:0.00002
# [300]	validation_0-mlogloss:0.00002
# [301]	validation_0-mlogloss:0.00002
# [302]	validation_0-mlogloss:0.00002
# [303]	validation_0-mlogloss:0.00002
# [304]	validation_0-mlogloss:0.00002
# [305]	validation_0-mlogloss:0.00002
# [306]	validation_0-mlogloss:0.00002
# [307]	validation_0-mlogloss:0.00002
# [308]	validation_0-mlogloss:0.00002
# [309]	validation_0-mlogloss:0.00002
# [310]	validation_0-mlogloss:0.00002
# [311]	validation_0-mlogloss:0.00002
# [312]	validation_0-mlogloss:0.00002
# [313]	validation_0-mlogloss:0.00002
# [314]	validation_0-mlogloss:0.00002
# [315]	validation_0-mlogloss:0.00002
# [316]	validation_0-mlogloss:0.00002
# [317]	validation_0-mlogloss:0.00002
# [318]	validation_0-mlogloss:0.00002
# [319]	validation_0-mlogloss:0.00002
# [320]	validation_0-mlogloss:0.00002
# [321]	validation_0-mlogloss:0.00002
# [322]	validation_0-mlogloss:0.00002
# [323]	validation_0-mlogloss:0.00002
# [324]	validation_0-mlogloss:0.00002
# [325]	validation_0-mlogloss:0.00002
# [326]	validation_0-mlogloss:0.00002
# [327]	validation_0-mlogloss:0.00002
# [328]	validation_0-mlogloss:0.00002
# [329]	validation_0-mlogloss:0.00002
# [330]	validation_0-mlogloss:0.00002
# [331]	validation_0-mlogloss:0.00002
# [332]	validation_0-mlogloss:0.00002
# [333]	validation_0-mlogloss:0.00002
# [334]	validation_0-mlogloss:0.00002
# [335]	validation_0-mlogloss:0.00002
# [336]	validation_0-mlogloss:0.00002
# [337]	validation_0-mlogloss:0.00002
# [338]	validation_0-mlogloss:0.00002
# [339]	validation_0-mlogloss:0.00002
# [340]	validation_0-mlogloss:0.00002
# [341]	validation_0-mlogloss:0.00002
# [342]	validation_0-mlogloss:0.00002
# [343]	validation_0-mlogloss:0.00002
# [344]	validation_0-mlogloss:0.00002
# [345]	validation_0-mlogloss:0.00002
# [346]	validation_0-mlogloss:0.00002
# [347]	validation_0-mlogloss:0.00002
# [348]	validation_0-mlogloss:0.00002
# [349]	validation_0-mlogloss:0.00002
# [350]	validation_0-mlogloss:0.00002
# [351]	validation_0-mlogloss:0.00002
# [352]	validation_0-mlogloss:0.00002
# [353]	validation_0-mlogloss:0.00002
# [354]	validation_0-mlogloss:0.00002
# [355]	validation_0-mlogloss:0.00002
# [356]	validation_0-mlogloss:0.00002
# [357]	validation_0-mlogloss:0.00002
# [358]	validation_0-mlogloss:0.00002
# [359]	validation_0-mlogloss:0.00002
# [360]	validation_0-mlogloss:0.00002
# [361]	validation_0-mlogloss:0.00002
# [362]	validation_0-mlogloss:0.00002
# [363]	validation_0-mlogloss:0.00002
# [364]	validation_0-mlogloss:0.00002
# [365]	validation_0-mlogloss:0.00002
# [366]	validation_0-mlogloss:0.00002
# [367]	validation_0-mlogloss:0.00002
# [368]	validation_0-mlogloss:0.00002
# [369]	validation_0-mlogloss:0.00002
# [370]	validation_0-mlogloss:0.00002
# [371]	validation_0-mlogloss:0.00002
# [372]	validation_0-mlogloss:0.00002
# [373]	validation_0-mlogloss:0.00002
# [374]	validation_0-mlogloss:0.00002
# [375]	validation_0-mlogloss:0.00002
# [376]	validation_0-mlogloss:0.00002
# [377]	validation_0-mlogloss:0.00002
# [378]	validation_0-mlogloss:0.00002
# [379]	validation_0-mlogloss:0.00002
# [380]	validation_0-mlogloss:0.00002
# [381]	validation_0-mlogloss:0.00002
# [382]	validation_0-mlogloss:0.00002
# [383]	validation_0-mlogloss:0.00002
# [384]	validation_0-mlogloss:0.00002
# [385]	validation_0-mlogloss:0.00002
# [386]	validation_0-mlogloss:0.00002
# [387]	validation_0-mlogloss:0.00002
# [388]	validation_0-mlogloss:0.00002
# [389]	validation_0-mlogloss:0.00002
# [390]	validation_0-mlogloss:0.00002
# [391]	validation_0-mlogloss:0.00002
# [392]	validation_0-mlogloss:0.00002
# [393]	validation_0-mlogloss:0.00002
# [394]	validation_0-mlogloss:0.00002
# [395]	validation_0-mlogloss:0.00002
# [396]	validation_0-mlogloss:0.00002
# [397]	validation_0-mlogloss:0.00002
# [398]	validation_0-mlogloss:0.00002
# [399]	validation_0-mlogloss:0.00002
# [400]	validation_0-mlogloss:0.00002
# [401]	validation_0-mlogloss:0.00002
# [402]	validation_0-mlogloss:0.00002
# [403]	validation_0-mlogloss:0.00002
# [404]	validation_0-mlogloss:0.00002
# [405]	validation_0-mlogloss:0.00002
# [406]	validation_0-mlogloss:0.00002
# [407]	validation_0-mlogloss:0.00002
# [408]	validation_0-mlogloss:0.00002
# [409]	validation_0-mlogloss:0.00002
# [410]	validation_0-mlogloss:0.00002
# [411]	validation_0-mlogloss:0.00002
# [412]	validation_0-mlogloss:0.00002
# [413]	validation_0-mlogloss:0.00002
# [414]	validation_0-mlogloss:0.00002
# [415]	validation_0-mlogloss:0.00002
# [416]	validation_0-mlogloss:0.00002
# [417]	validation_0-mlogloss:0.00002
# [418]	validation_0-mlogloss:0.00002
# [419]	validation_0-mlogloss:0.00002
# [420]	validation_0-mlogloss:0.00002
# [421]	validation_0-mlogloss:0.00002
# [422]	validation_0-mlogloss:0.00002
# [423]	validation_0-mlogloss:0.00002
# [424]	validation_0-mlogloss:0.00002
# [425]	validation_0-mlogloss:0.00002
# [426]	validation_0-mlogloss:0.00002
# [427]	validation_0-mlogloss:0.00002
# [428]	validation_0-mlogloss:0.00002
# [429]	validation_0-mlogloss:0.00002
# [430]	validation_0-mlogloss:0.00002
# [431]	validation_0-mlogloss:0.00002
# [432]	validation_0-mlogloss:0.00002
# [433]	validation_0-mlogloss:0.00002
# [434]	validation_0-mlogloss:0.00002
# [435]	validation_0-mlogloss:0.00002
# [436]	validation_0-mlogloss:0.00002
# [437]	validation_0-mlogloss:0.00002
# [438]	validation_0-mlogloss:0.00002
# [439]	validation_0-mlogloss:0.00002
# [440]	validation_0-mlogloss:0.00002
# [441]	validation_0-mlogloss:0.00002
# [442]	validation_0-mlogloss:0.00002
# [443]	validation_0-mlogloss:0.00002
# [444]	validation_0-mlogloss:0.00002
# [445]	validation_0-mlogloss:0.00002
# [446]	validation_0-mlogloss:0.00002
# [447]	validation_0-mlogloss:0.00002
# [448]	validation_0-mlogloss:0.00002
# [449]	validation_0-mlogloss:0.00002
# [450]	validation_0-mlogloss:0.00002
# [451]	validation_0-mlogloss:0.00002
# [452]	validation_0-mlogloss:0.00002
# [453]	validation_0-mlogloss:0.00002
# [454]	validation_0-mlogloss:0.00002
# [455]	validation_0-mlogloss:0.00002
# [456]	validation_0-mlogloss:0.00002
# [457]	validation_0-mlogloss:0.00002
# [458]	validation_0-mlogloss:0.00002
# [459]	validation_0-mlogloss:0.00002
# [460]	validation_0-mlogloss:0.00002
# [461]	validation_0-mlogloss:0.00002
# [462]	validation_0-mlogloss:0.00002
# [463]	validation_0-mlogloss:0.00002
# [464]	validation_0-mlogloss:0.00002
# [465]	validation_0-mlogloss:0.00002
# [466]	validation_0-mlogloss:0.00002
# [467]	validation_0-mlogloss:0.00002
# [468]	validation_0-mlogloss:0.00002
# [469]	validation_0-mlogloss:0.00002
# [470]	validation_0-mlogloss:0.00002
# [471]	validation_0-mlogloss:0.00002
# [472]	validation_0-mlogloss:0.00002
# [473]	validation_0-mlogloss:0.00002
# [474]	validation_0-mlogloss:0.00002
# [475]	validation_0-mlogloss:0.00002
# [476]	validation_0-mlogloss:0.00002
# [477]	validation_0-mlogloss:0.00002
# [478]	validation_0-mlogloss:0.00002
# [479]	validation_0-mlogloss:0.00002
# [480]	validation_0-mlogloss:0.00002
# [481]	validation_0-mlogloss:0.00002
# [482]	validation_0-mlogloss:0.00002
# [483]	validation_0-mlogloss:0.00002
# [484]	validation_0-mlogloss:0.00002
# [485]	validation_0-mlogloss:0.00002
# [486]	validation_0-mlogloss:0.00002
# [487]	validation_0-mlogloss:0.00002
# [488]	validation_0-mlogloss:0.00002
# [489]	validation_0-mlogloss:0.00002
# [490]	validation_0-mlogloss:0.00002
# [491]	validation_0-mlogloss:0.00002
# [492]	validation_0-mlogloss:0.00002
# [493]	validation_0-mlogloss:0.00002
# [494]	validation_0-mlogloss:0.00002
# [495]	validation_0-mlogloss:0.00002
# [496]	validation_0-mlogloss:0.00002
# [497]	validation_0-mlogloss:0.00002
# [498]	validation_0-mlogloss:0.00002
# [499]	validation_0-mlogloss:0.00002
# [500]	validation_0-mlogloss:0.00002
# [501]	validation_0-mlogloss:0.00002
# [502]	validation_0-mlogloss:0.00002
# [503]	validation_0-mlogloss:0.00002
# [504]	validation_0-mlogloss:0.00002
# [505]	validation_0-mlogloss:0.00002
# [506]	validation_0-mlogloss:0.00002
# [507]	validation_0-mlogloss:0.00002
# [508]	validation_0-mlogloss:0.00002
# [509]	validation_0-mlogloss:0.00002
# [510]	validation_0-mlogloss:0.00002
# [511]	validation_0-mlogloss:0.00002
# [512]	validation_0-mlogloss:0.00002
# [513]	validation_0-mlogloss:0.00002
# [514]	validation_0-mlogloss:0.00002
# [515]	validation_0-mlogloss:0.00002
# [516]	validation_0-mlogloss:0.00002
# [517]	validation_0-mlogloss:0.00002
# [518]	validation_0-mlogloss:0.00002
# [519]	validation_0-mlogloss:0.00002
# [520]	validation_0-mlogloss:0.00002
# [521]	validation_0-mlogloss:0.00002
# [522]	validation_0-mlogloss:0.00002
# [523]	validation_0-mlogloss:0.00002
# [524]	validation_0-mlogloss:0.00002
# [525]	validation_0-mlogloss:0.00002
# [526]	validation_0-mlogloss:0.00002
# [527]	validation_0-mlogloss:0.00002
# [528]	validation_0-mlogloss:0.00002
# [529]	validation_0-mlogloss:0.00002
# [530]	validation_0-mlogloss:0.00002
# [531]	validation_0-mlogloss:0.00002
# [532]	validation_0-mlogloss:0.00002
# [533]	validation_0-mlogloss:0.00002
# [534]	validation_0-mlogloss:0.00002
# [535]	validation_0-mlogloss:0.00002
# [536]	validation_0-mlogloss:0.00002
# [537]	validation_0-mlogloss:0.00002
# [538]	validation_0-mlogloss:0.00002
# [539]	validation_0-mlogloss:0.00002
# [540]	validation_0-mlogloss:0.00002
# [541]	validation_0-mlogloss:0.00002
# [542]	validation_0-mlogloss:0.00002
# [543]	validation_0-mlogloss:0.00002
# [544]	validation_0-mlogloss:0.00002
# [545]	validation_0-mlogloss:0.00002
# [546]	validation_0-mlogloss:0.00002
# [547]	validation_0-mlogloss:0.00002
# [548]	validation_0-mlogloss:0.00002
# [549]	validation_0-mlogloss:0.00002
# [550]	validation_0-mlogloss:0.00002
# [551]	validation_0-mlogloss:0.00002
# [552]	validation_0-mlogloss:0.00002
# [553]	validation_0-mlogloss:0.00002
# [554]	validation_0-mlogloss:0.00002
# [555]	validation_0-mlogloss:0.00002
# [556]	validation_0-mlogloss:0.00002
# [557]	validation_0-mlogloss:0.00002
# [558]	validation_0-mlogloss:0.00002
# [559]	validation_0-mlogloss:0.00002
# [560]	validation_0-mlogloss:0.00002
# [561]	validation_0-mlogloss:0.00002
# [562]	validation_0-mlogloss:0.00002
# [563]	validation_0-mlogloss:0.00002
# [564]	validation_0-mlogloss:0.00002
# [565]	validation_0-mlogloss:0.00002
# [566]	validation_0-mlogloss:0.00002
# [567]	validation_0-mlogloss:0.00002
# [568]	validation_0-mlogloss:0.00002
# [569]	validation_0-mlogloss:0.00002
# [570]	validation_0-mlogloss:0.00002
# [571]	validation_0-mlogloss:0.00002
# [572]	validation_0-mlogloss:0.00002
# [573]	validation_0-mlogloss:0.00002
# [574]	validation_0-mlogloss:0.00002
# [575]	validation_0-mlogloss:0.00002
# [576]	validation_0-mlogloss:0.00002
# [577]	validation_0-mlogloss:0.00002
# [578]	validation_0-mlogloss:0.00002
# [579]	validation_0-mlogloss:0.00002
# [580]	validation_0-mlogloss:0.00002
# [581]	validation_0-mlogloss:0.00002
# [582]	validation_0-mlogloss:0.00002
# [583]	validation_0-mlogloss:0.00002
# [584]	validation_0-mlogloss:0.00002
# [585]	validation_0-mlogloss:0.00002
# [586]	validation_0-mlogloss:0.00002
# [587]	validation_0-mlogloss:0.00002
# [588]	validation_0-mlogloss:0.00002
# [589]	validation_0-mlogloss:0.00002
# [590]	validation_0-mlogloss:0.00002
# [591]	validation_0-mlogloss:0.00002
# [592]	validation_0-mlogloss:0.00002
# [593]	validation_0-mlogloss:0.00002
# [594]	validation_0-mlogloss:0.00002
# [595]	validation_0-mlogloss:0.00002
# [596]	validation_0-mlogloss:0.00002
# [597]	validation_0-mlogloss:0.00002
# [598]	validation_0-mlogloss:0.00002
# [599]	validation_0-mlogloss:0.00002

# %%
# 加权融合模型，如果w没有变，就是均值融合
def Weighted_method(test_pre2,test_pre3,w=[1/2,1/2]):
    Weighted_result = w[0]*pd.Series(test_pre2)+w[1]*pd.Series(test_pre3)
    return Weighted_result

# 初始权重，可以进行自定义，这里我们随便设置一个权重
w=[1/4,3/4]
train_pre = Weighted_method(train_lgb,train_xgb,w)
test_pre = Weighted_method(test_lgb,test_xgb,w)
# for i1 in range(len(train_pre)):
#     train_pre[i1]=int(train_pre[i1]+0.5)
# for i2 in range(len(test_pre)):
#     test_pre[i2]=int(test_pre[i2]+0.5)
def cut(data):
    d=data.copy()
    for i in range(len(d)):
        d[i]=int(d[i]+0.5)
    return d
# print(test_pre)
# print('train score : ', accuracy_score(cut(train_rf), Y_new_train,normalize=False))
# print('test score : ', accuracy_score(cut(test_rf), Y_new_test,normalize=False))
print('train score : ', accuracy_score(cut(train_lgb), Y_new_train,normalize=False))
print('test score : ', accuracy_score(cut(test_lgb), Y_new_test,normalize=False))

print('train score : ', accuracy_score(cut(train_xgb), Y_new_train,normalize=False))
print('test score : ', accuracy_score(cut(test_xgb), Y_new_test,normalize=False))
print('train score : ', accuracy_score(cut(train_pre), Y_new_train,normalize=False))
print('test score : ', accuracy_score(cut(test_pre), Y_new_test,normalize=False))
# Out:
# train score :  79991
# test score :  19799
# train score :  80000
# test score :  19891
# train score :  79999
# test score :  19868

# %%
def abs_sum(y_tru, y_pre):
    y_pre = pd.get_dummies(data=cut(y_pre))
#     print(y_pre)
    y_tru = pd.get_dummies(data=y_tru)
    y_pre = np.array(y_pre)
    y_tru = np.array(y_tru)
    loss = sum(sum(abs(y_pre - y_tru)))
    return loss
# print(abs_sum(Y_new_test,test_pre))
Y_new_test=Y_new_test.reset_index(drop = True)
print(abs_sum(Y_validation,test_pre))
#512
# Out:
# 512

# %%
## 第一层

stacking_X_train = pd.DataFrame()
# stacking_X_train['Method_1'] = train_rf
stacking_X_train['Method_2'] = train_lgb
stacking_X_train['Method_3'] = train_xgb

stacking_X_val = pd.DataFrame()
# stacking_X_val['Method_1'] = test_rf
stacking_X_val['Method_2'] = test_lgb
stacking_X_val['Method_3'] = test_xgb

# %%
def abs_sum(y_tru, y_pre):
    y_pre=pd.get_dummies(data=y_pre)
    y_tru = pd.get_dummies(data=y_tru)
    y_pre = np.array(y_pre)
    y_tru = np.array(y_tru)
    loss = sum(sum(abs(y_pre - y_tru)))
    return loss
# 第二层是用random forest
model_lr_stacking = build_model_lgb(stacking_X_train,Y_new_train)

## 训练集
train_pre_Stacking = model_lr_stacking.predict(stacking_X_train)
print(abs_sum(train_pre_Stacking,Y_new_train))
## 验证集
val_pre_Stacking = model_lr_stacking.predict(stacking_X_val)
print(abs_sum(val_pre_Stacking,Y_new_test))
#0 512
# Out:
# 0
# 512

# %%
def abs_sum(y_tru, y_pre):
    y_tru = pd.get_dummies(data=y_tru)
    y_pre = np.array(y_pre)
    y_tru = np.array(y_tru)
    loss = sum(sum(abs(y_pre - y_tru)))
    return loss

pre = model_cnn.predict(X_validation)
print(abs_sum(Y_validation, pre))
# Out:
# 348.5404987335205

# %%
test_data=pre.copy()
for ii in range(20000):
    for jj in range(4):
        test_data[ii][jj]=int(test_data[ii][jj]+0.5)

print(abs_sum(Y_validation, test_data))
#50epoch 384(cut338)
#30 470(cut394)
#40 330(cut295) bs128 314(cut285)adam sgd401(cut349) adam326(cut286) 
#40 pooling 16 8 adam390(cut335) 
#30 sgd439(cut354)16 7 3 sgd309(cut294)16 16 16 adam341(cut305)
# Out:
# 317.0

# %%
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
import lightgbm as lgb
def build_model_rf(X_train,y_train):
    model = RandomForestRegressor(n_estimators = 100)
    model.fit(X_train, y_train)
    return model


def build_model_lgb(X_train,y_train):
    model = lgb.LGBMRegressor(num_leaves=63,learning_rate = 0.1,n_estimators = 100)
    model.fit(X_train, y_train)
    return model

# %%
def oneHotRound(val_p):
    d=val_p.copy()
    for i in range(len(val_p)):
        d[i]=int(d[i]+0.5)
    d=pd.get_dummies(data=d)

# %%
print('predict rf...')
model_rf = build_model_rf(train_X,train_Y)
val_rf = model_rf.predict(train_X)
subA_rf = model_rf.predict(X_validation)
print(abs_sum(Y_validation, oneHotRound(subA_rf)))


print('predict lgb...')
model_lgb = build_model_lgb(train_X,train_Y)
val_lgb = model_lgb.predict(train_X)
subA_lgb = model_lgb.predict(X_validation)
print(abs_sum(Y_validation, oneHotRound(subA_lgb)))


print('predict NN...')
val_nn = model.predict(train_X)
subA_nn = model.predict(X_validation)
print(abs_sum(Y_validation, subA_nn))
